# %%
password = {}
while True:
    option = input('\n\nChoose: \n1. Login\n2. See Passwords\n3. Set Passwords\n4. Exit\n')
    if option == '1':
        name = input('Enter your name: ')
        pwd = input('Set password to access your `Password Manager` account (only need to do this once): ')
        print('You are good to go!')
    elif option == '2':
        name_1 = input('Enter your name: ')
        pwd_1 = input('Enter your password: ')
        if pwd_1 != pwd:
            print('Incorrect password. You cannot access your account. Login again.')
        else:
            print('Passwords:',password)
    elif option == '3':
        name_1 = input('Enter your name: ')
        pwd_1 = input('Enter your password: ')
        if pwd_1 != pwd:
            print('Incorrect password. You cannot access your account. Login again.')
        else:
            data = input('Enter username and password separated by space: ')
            key, value = (data.strip().split(' '))
            password[key] = value
            print('Saved Successfully!')
    else:
        print('Exiting..')
        break
# Out:
# Choose:
# 1. Login
# 2. See Passwords
# 3. Set Passwords
# 4. Exit
# 1
# Enter your name: Manasi
# Set password to access your `Password Manager` account (only need to do this once): sb
# You are good to go!
#
#
# Choose:
# 1. Login
# 2. See Passwords
# 3. Set Passwords
# 4. Exit
# 2
# Enter your name: Manasi
# Enter your password: sb
# Passwords: {}
#
#
# Choose:
# 1. Login
# 2. See Passwords
# 3. Set Passwords
# 4. Exit
# 3
# Enter your name: Manasi
# Enter your password: sB
# Incorrect password. You cannot access your account. Login again.
#
#
# Choose:
# 1. Login
# 2. See Passwords
# 3. Set Passwords
# 4. Exit
# 3
# Enter your name: Manasi
# Enter your password: sb
# Enter username and password separated by space: pinterest M01
# Saved Successfully!
#
#
# Choose:
# 1. Login
# 2. See Passwords
# 3. Set Passwords
# 4. Exit
# 2
# Enter your name: Manasi
# Enter your password: sb
# Passwords: {'pinterest': 'M01'}
#
#
# Choose:
# 1. Login
# 2. See Passwords
# 3. Set Passwords
# ...
